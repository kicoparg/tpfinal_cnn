# %%
# !mkdir /content/output

# %%
from keras.preprocessing.image import load_img, save_img, img_to_array
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse

from keras.applications import vgg19
from keras import backend as K
from pathlib import Path

# %%
import tensorflow as tf
print(tf.__version__)
tf.compat.v1.disable_eager_execution()
# Out:
# 2.3.0

# %%
base_image_path = Path("/content/familia.jpg")
style_reference_image_path = Path("/content/milo-lockett.jpg")
result_prefix = Path("/content/output")
iterations = 100

# %%
total_variation_weight = 0.1
style_weight = 10
content_weight = 1

# %%
# Definimos el tamaño de las imágenes a utilizar
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
img_content = load_img(base_image_path, target_size=(img_nrows, img_ncols))
img_style = load_img(style_reference_image_path, target_size=(img_nrows, img_ncols))

# %%
img_content
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=493x400 at 0x7FE500138630>

# %%
img_style
# Out:
# <PIL.Image.Image image mode=RGB size=493x400 at 0x7FE500138588>

# %%
def deprocess_image(x):
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
# get tensor representations of our images
# K.variable convierte un numpy array en un tensor, para 
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))

# %%
combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# %%
# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# %%
# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')

# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Out:
# Model loaded.

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %%
def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def total_variation_loss(x):
    assert K.ndim(x) == 4
    a = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
    b = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# Armamos la loss total
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                            combination_features)

feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :] 
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(feature_layers)) * sl
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
grads = K.gradients(loss, combination_image)

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs += grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)

# %%
def eval_loss_and_grads(x):
    x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.

# %%
class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %%
evaluator = Evaluator()

# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())

    #fname = result_prefix / ('output_at_iteration_%d.png' % i)
    fname = result_prefix / ('output_S%02d_C%02d_iter_%02d.png' % (style_weight,content_weight, i))
    save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 67872800000.0
# Image saved as /content/output/output_S10_C01_iter_00.png
# Iteration 0 completed in 5s
# Start of iteration 1
# Current loss value: 31347765000.0
# Image saved as /content/output/output_S10_C01_iter_01.png
# Iteration 1 completed in 5s
# Start of iteration 2
# Current loss value: 21182935000.0
# Image saved as /content/output/output_S10_C01_iter_02.png
# Iteration 2 completed in 5s
# Start of iteration 3
# Current loss value: 16736534000.0
# Image saved as /content/output/output_S10_C01_iter_03.png
# Iteration 3 completed in 5s
# Start of iteration 4
# Current loss value: 14135746000.0
# Image saved as /content/output/output_S10_C01_iter_04.png
# Iteration 4 completed in 5s
# Start of iteration 5
# Current loss value: 12454254000.0
# Image saved as /content/output/output_S10_C01_iter_05.png
# Iteration 5 completed in 5s
# Start of iteration 6
# Current loss value: 11147124000.0
# Image saved as /content/output/output_S10_C01_iter_06.png
# Iteration 6 completed in 5s
# Start of iteration 7
# Current loss value: 10107717000.0
# Image saved as /content/output/output_S10_C01_iter_07.png
# Iteration 7 completed in 5s
# Start of iteration 8
# Current loss value: 9342864000.0
# Image saved as /content/output/output_S10_C01_iter_08.png
# Iteration 8 completed in 5s
# Start of iteration 9
# Current loss value: 8708296000.0
# Image saved as /content/output/output_S10_C01_iter_09.png
# Iteration 9 completed in 5s
# Start of iteration 10
# Current loss value: 8195667000.0
# Image saved as /content/output/output_S10_C01_iter_10.png
# Iteration 10 completed in 5s
# Start of iteration 11
# Current loss value: 7717568500.0
# Image saved as /content/output/output_S10_C01_iter_11.png
# Iteration 11 completed in 5s
# Start of iteration 12
# Current loss value: 7361445000.0
# Image saved as /content/output/output_S10_C01_iter_12.png
# Iteration 12 completed in 5s
# Start of iteration 13
# Current loss value: 6999419000.0
# Image saved as /content/output/output_S10_C01_iter_13.png
# Iteration 13 completed in 5s
# Start of iteration 14
# Current loss value: 6669970400.0
# Image saved as /content/output/output_S10_C01_iter_14.png
# Iteration 14 completed in 5s
# Start of iteration 15
# Current loss value: 6421582000.0
# Image saved as /content/output/output_S10_C01_iter_15.png
# Iteration 15 completed in 5s
# Start of iteration 16
# Current loss value: 6187196400.0
# Image saved as /content/output/output_S10_C01_iter_16.png
# Iteration 16 completed in 5s
# Start of iteration 17
# Current loss value: 5987408000.0
# Image saved as /content/output/output_S10_C01_iter_17.png
# Iteration 17 completed in 5s
# Start of iteration 18
# Current loss value: 5805959000.0
# Image saved as /content/output/output_S10_C01_iter_18.png
# Iteration 18 completed in 5s
# Start of iteration 19
# Current loss value: 5645067300.0
# Image saved as /content/output/output_S10_C01_iter_19.png
# Iteration 19 completed in 5s
# Start of iteration 20
# Current loss value: 5492718000.0
# Image saved as /content/output/output_S10_C01_iter_20.png
# Iteration 20 completed in 5s
# Start of iteration 21
# Current loss value: 5329817000.0
# Image saved as /content/output/output_S10_C01_iter_21.png
# Iteration 21 completed in 5s
# Start of iteration 22
# Current loss value: 5207234000.0
# Image saved as /content/output/output_S10_C01_iter_22.png
# Iteration 22 completed in 5s
# Start of iteration 23
# Current loss value: 5076032000.0
# Image saved as /content/output/output_S10_C01_iter_23.png
# Iteration 23 completed in 5s
# Start of iteration 24
# Current loss value: 4961367000.0
# Image saved as /content/output/output_S10_C01_iter_24.png
# Iteration 24 completed in 5s
# Start of iteration 25
# Current loss value: 4868716000.0
# Image saved as /content/output/output_S10_C01_iter_25.png
# Iteration 25 completed in 5s
# Start of iteration 26
# Current loss value: 4775762400.0
# Image saved as /content/output/output_S10_C01_iter_26.png
# Iteration 26 completed in 5s
# Start of iteration 27
# Current loss value: 4686994000.0
# Image saved as /content/output/output_S10_C01_iter_27.png
# Iteration 27 completed in 5s
# Start of iteration 28
# Current loss value: 4599732000.0
# Image saved as /content/output/output_S10_C01_iter_28.png
# Iteration 28 completed in 5s
# Start of iteration 29
# Current loss value: 4520858000.0
# Image saved as /content/output/output_S10_C01_iter_29.png
# Iteration 29 completed in 5s
# Start of iteration 30
# Current loss value: 4453437000.0
# Image saved as /content/output/output_S10_C01_iter_30.png
# Iteration 30 completed in 5s
# Start of iteration 31
# Current loss value: 4388171300.0
# Image saved as /content/output/output_S10_C01_iter_31.png
# Iteration 31 completed in 5s
# Start of iteration 32
# Current loss value: 4322928600.0
# Image saved as /content/output/output_S10_C01_iter_32.png
# Iteration 32 completed in 5s
# Start of iteration 33
# Current loss value: 4264366800.0
# Image saved as /content/output/output_S10_C01_iter_33.png
# Iteration 33 completed in 5s
# Start of iteration 34
# Current loss value: 4215214600.0
# Image saved as /content/output/output_S10_C01_iter_34.png
# Iteration 34 completed in 5s
# Start of iteration 35
# Current loss value: 4147767800.0
# Image saved as /content/output/output_S10_C01_iter_35.png
# Iteration 35 completed in 5s
# Start of iteration 36
# Current loss value: 4086386700.0
# Image saved as /content/output/output_S10_C01_iter_36.png
# Iteration 36 completed in 5s
# Start of iteration 37
# Current loss value: 4039822800.0
# Image saved as /content/output/output_S10_C01_iter_37.png
# Iteration 37 completed in 5s
# Start of iteration 38
# Current loss value: 3987850000.0
# Image saved as /content/output/output_S10_C01_iter_38.png
# Iteration 38 completed in 5s
# Start of iteration 39
# Current loss value: 3943038700.0
# Image saved as /content/output/output_S10_C01_iter_39.png
# Iteration 39 completed in 5s
# Start of iteration 40
# Current loss value: 3906264600.0
# Image saved as /content/output/output_S10_C01_iter_40.png
# Iteration 40 completed in 5s
# Start of iteration 41
# Current loss value: 3869945300.0
# Image saved as /content/output/output_S10_C01_iter_41.png
# Iteration 41 completed in 5s
# Start of iteration 42
# Current loss value: 3829425400.0
# Image saved as /content/output/output_S10_C01_iter_42.png
# Iteration 42 completed in 5s
# Start of iteration 43
# Current loss value: 3792131800.0
# Image saved as /content/output/output_S10_C01_iter_43.png
# Iteration 43 completed in 5s
# Start of iteration 44
# Current loss value: 3758688800.0
# Image saved as /content/output/output_S10_C01_iter_44.png
# Iteration 44 completed in 5s
# Start of iteration 45
# Current loss value: 3727657000.0
# Image saved as /content/output/output_S10_C01_iter_45.png
# Iteration 45 completed in 5s
# Start of iteration 46
# Current loss value: 3692499200.0
# Image saved as /content/output/output_S10_C01_iter_46.png
# Iteration 46 completed in 5s
# Start of iteration 47
# Current loss value: 3658211300.0
# Image saved as /content/output/output_S10_C01_iter_47.png
# Iteration 47 completed in 5s
# Start of iteration 48
# Current loss value: 3628381000.0
# Image saved as /content/output/output_S10_C01_iter_48.png
# Iteration 48 completed in 5s
# Start of iteration 49
# Current loss value: 3598651000.0
# Image saved as /content/output/output_S10_C01_iter_49.png
# Iteration 49 completed in 5s
# Start of iteration 50
# Current loss value: 3568215600.0
# Image saved as /content/output/output_S10_C01_iter_50.png
# Iteration 50 completed in 5s
# Start of iteration 51
# Current loss value: 3542744000.0
# Image saved as /content/output/output_S10_C01_iter_51.png
# Iteration 51 completed in 6s
# Start of iteration 52
# Current loss value: 3518280400.0
# Image saved as /content/output/output_S10_C01_iter_52.png
# Iteration 52 completed in 5s
# Start of iteration 53
# Current loss value: 3491527700.0
# Image saved as /content/output/output_S10_C01_iter_53.png
# Iteration 53 completed in 5s
# Start of iteration 54
# Current loss value: 3461829000.0
# Image saved as /content/output/output_S10_C01_iter_54.png
# Iteration 54 completed in 5s
# Start of iteration 55
# Current loss value: 3435134200.0
# Image saved as /content/output/output_S10_C01_iter_55.png
# Iteration 55 completed in 5s
# Start of iteration 56
# Current loss value: 3405603000.0
# Image saved as /content/output/output_S10_C01_iter_56.png
# Iteration 56 completed in 5s
# Start of iteration 57
# Current loss value: 3381092600.0
# Image saved as /content/output/output_S10_C01_iter_57.png
# Iteration 57 completed in 5s
# Start of iteration 58
# Current loss value: 3354787300.0
# Image saved as /content/output/output_S10_C01_iter_58.png
# Iteration 58 completed in 5s
# Start of iteration 59
# Current loss value: 3329106200.0
# Image saved as /content/output/output_S10_C01_iter_59.png
# Iteration 59 completed in 5s
# Start of iteration 60
# Current loss value: 3305164800.0
# Image saved as /content/output/output_S10_C01_iter_60.png
# Iteration 60 completed in 5s
# Start of iteration 61
# Current loss value: 3284345300.0
# Image saved as /content/output/output_S10_C01_iter_61.png
# Iteration 61 completed in 5s
# Start of iteration 62
# Current loss value: 3265456600.0
# Image saved as /content/output/output_S10_C01_iter_62.png
# Iteration 62 completed in 5s
# Start of iteration 63
# Current loss value: 3248052700.0
# Image saved as /content/output/output_S10_C01_iter_63.png
# Iteration 63 completed in 5s
# Start of iteration 64
# Current loss value: 3223238100.0
# Image saved as /content/output/output_S10_C01_iter_64.png
# Iteration 64 completed in 5s
# Start of iteration 65
# Current loss value: 3201339000.0
# Image saved as /content/output/output_S10_C01_iter_65.png
# Iteration 65 completed in 5s
# Start of iteration 66
# Current loss value: 3185783300.0
# Image saved as /content/output/output_S10_C01_iter_66.png
# Iteration 66 completed in 5s
# Start of iteration 67
# Current loss value: 3169453000.0
# Image saved as /content/output/output_S10_C01_iter_67.png
# Iteration 67 completed in 5s
# Start of iteration 68
# Current loss value: 3155336000.0
# Image saved as /content/output/output_S10_C01_iter_68.png
# Iteration 68 completed in 5s
# Start of iteration 69
# Current loss value: 3142489900.0
# Image saved as /content/output/output_S10_C01_iter_69.png
# Iteration 69 completed in 5s
# Start of iteration 70
# Current loss value: 3130107100.0
# Image saved as /content/output/output_S10_C01_iter_70.png
# Iteration 70 completed in 5s
# Start of iteration 71
# Current loss value: 3118857500.0
# Image saved as /content/output/output_S10_C01_iter_71.png
# Iteration 71 completed in 5s
# Start of iteration 72
# Current loss value: 3105029600.0
# Image saved as /content/output/output_S10_C01_iter_72.png
# Iteration 72 completed in 5s
# Start of iteration 73
# Current loss value: 3091430400.0
# Image saved as /content/output/output_S10_C01_iter_73.png
# Iteration 73 completed in 5s
# Start of iteration 74
# Current loss value: 3079656400.0
# Image saved as /content/output/output_S10_C01_iter_74.png
# Iteration 74 completed in 5s
# Start of iteration 75
# Current loss value: 3068996400.0
# Image saved as /content/output/output_S10_C01_iter_75.png
# Iteration 75 completed in 5s
# Start of iteration 76
# Current loss value: 3056945400.0
# Image saved as /content/output/output_S10_C01_iter_76.png
# Iteration 76 completed in 5s
# Start of iteration 77
# Current loss value: 3045371100.0
# Image saved as /content/output/output_S10_C01_iter_77.png
# Iteration 77 completed in 5s
# Start of iteration 78
# Current loss value: 3032504000.0
# Image saved as /content/output/output_S10_C01_iter_78.png
# Iteration 78 completed in 5s
# Start of iteration 79
# Current loss value: 3021900300.0
# Image saved as /content/output/output_S10_C01_iter_79.png
# Iteration 79 completed in 5s
# Start of iteration 80
# Current loss value: 3007101700.0
# Image saved as /content/output/output_S10_C01_iter_80.png
# Iteration 80 completed in 5s
# Start of iteration 81
# Current loss value: 2992513500.0
# Image saved as /content/output/output_S10_C01_iter_81.png
# Iteration 81 completed in 5s
# Start of iteration 82
# Current loss value: 2978455800.0
# Image saved as /content/output/output_S10_C01_iter_82.png
# Iteration 82 completed in 5s
# Start of iteration 83
# Current loss value: 2964751000.0
# Image saved as /content/output/output_S10_C01_iter_83.png
# Iteration 83 completed in 5s
# Start of iteration 84
# Current loss value: 2955011600.0
# Image saved as /content/output/output_S10_C01_iter_84.png
# Iteration 84 completed in 5s
# Start of iteration 85
# Current loss value: 2945535200.0
# Image saved as /content/output/output_S10_C01_iter_85.png
# Iteration 85 completed in 5s
# Start of iteration 86
# Current loss value: 2937468000.0
# Image saved as /content/output/output_S10_C01_iter_86.png
# Iteration 86 completed in 5s
# Start of iteration 87
# Current loss value: 2928708600.0
# Image saved as /content/output/output_S10_C01_iter_87.png
# Iteration 87 completed in 5s
# Start of iteration 88
# Current loss value: 2918943000.0
# Image saved as /content/output/output_S10_C01_iter_88.png
# Iteration 88 completed in 5s
# Start of iteration 89
# Current loss value: 2910742500.0
# Image saved as /content/output/output_S10_C01_iter_89.png
# Iteration 89 completed in 5s
# Start of iteration 90
# Current loss value: 2902232600.0
# Image saved as /content/output/output_S10_C01_iter_90.png
# Iteration 90 completed in 5s
# Start of iteration 91
# Current loss value: 2894752000.0
# Image saved as /content/output/output_S10_C01_iter_91.png
# Iteration 91 completed in 5s
# Start of iteration 92
# Current loss value: 2886595000.0
# Image saved as /content/output/output_S10_C01_iter_92.png
# Iteration 92 completed in 5s
# Start of iteration 93
# Current loss value: 2878854100.0
# Image saved as /content/output/output_S10_C01_iter_93.png
# Iteration 93 completed in 5s
# Start of iteration 94
# Current loss value: 2872041000.0
# Image saved as /content/output/output_S10_C01_iter_94.png
# Iteration 94 completed in 5s
# Start of iteration 95
# Current loss value: 2864392200.0
# Image saved as /content/output/output_S10_C01_iter_95.png
# Iteration 95 completed in 5s
# Start of iteration 96
# Current loss value: 2857132000.0
# Image saved as /content/output/output_S10_C01_iter_96.png
# Iteration 96 completed in 5s
# Start of iteration 97
# Current loss value: 2850514200.0
# Image saved as /content/output/output_S10_C01_iter_97.png
# Iteration 97 completed in 5s
# Start of iteration 98
# Current loss value: 2843702800.0
# Image saved as /content/output/output_S10_C01_iter_98.png
# Iteration 98 completed in 5s
# Start of iteration 99
# Current loss value: 2836200400.0
# Image saved as /content/output/output_S10_C01_iter_99.png
# Iteration 99 completed in 5s
